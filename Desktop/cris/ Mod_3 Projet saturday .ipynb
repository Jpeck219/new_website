# %% [markdown]
# ## Trying

# %%
import pandas as pd

# %%
import requests
import json
from yelp.client import Client

# %%
# pip install yelp

# %%
# jonathan
client_id = 'E1AQMelCA8e5oZKc-yWfhg'

key= '43p9tSwkbBOVCEUsTURSCAQOXKzbiPIa5r0fTt3cKZT6W2zSXaT3nGQV4MUgu6EPQHKvPeqbio9N6sUMM3Ycug_3xphoP48sFtUf9wx-JdAWLPzGhZZP2c4hTF8SXXYx'

# %%
term = 'Axe Throwing' # 'Ramen'
location = 'Brooklyn' # 'LES'
SEARCH_LIMIT = 10

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)
print(response) # 200
print(type(response.text)) # string jason format from here you have format using json
print(response.text) # term these into a dataframe
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "X0DNGKUQPjf0AfaXfXU2Qg", "alias": "kick-axe-throwing-brooklyn-2", "name": "Kick Axe Throwing", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Q12f9Wz9kiRN2Gzlg9gSfA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/kick-axe-throwing-brooklyn-2?adjust_creative=E1AQMelCA8e5oZKc-yWfhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E1AQMelCA8e5oZKc-yWfhg", "review_count": 290, "categories": [{"alias": "axethrowing", "title": "Axe Throwing"}], "rating": 4.5, "coordinates": {"latitude": 40.6790268, "longitude": -73.983077}, "transactions": [], "location": {"address1": "622 Degraw St", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["622 Degraw St", "Brooklyn, NY 11217"]}, "phone": "+18335425293", "display_phone": "(833) 542-5293", "distance": 4733.616620254917}, {"id": "4E6BkrEVf_0TjRVYE7gxeQ", "alias": "bury-the-hatchet-brooklyn-axe-throwing-brooklyn-2", "name": "Bury the Hatchet Brooklyn - Axe Throwing", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/SH8_Nwmd13LkntwuzcEPeg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/bury-the-hatchet-brooklyn-axe-throwing-brooklyn-2?adjust_creative=E1AQMelCA8e5oZKc-yWfhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E1AQMelCA8e5oZKc-yWfhg", "review_count": 69, "categories": [{"alias": "axethrowing", "title": "Axe Throwing"}, {"alias": "teambuilding", "title": "Team Building Activities"}], "rating": 4.5, "coordinates": {"latitude": 40.7283195, "longitude": -73.9600679}, "transactions": [], "location": {"address1": "25 Noble St", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11222", "country": "US", "state": "NY", "display_address": ["25 Noble St", "Brooklyn, NY 11222"]}, "phone": "+19172439696", "display_phone": "(917) 243-9696", "distance": 8652.979400045351}, {"id": "PhEkSzYZHKYS7uyXePmkMw", "alias": "axes-and-arrows-long-island-city-2", "name": "Axes And Arrows", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/gfBB-MNosVg6x6eOo8vQKQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/axes-and-arrows-long-island-city-2?adjust_creative=E1AQMelCA8e5oZKc-yWfhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E1AQMelCA8e5oZKc-yWfhg", "review_count": 25, "categories": [{"alias": "axethrowing", "title": "Axe Throwing"}, {"alias": "archery", "title": "Archery"}], "rating": 5.0, "coordinates": {"latitude": 40.7425127, "longitude": -73.933816}, "transactions": [], "location": {"address1": "47- 11 Van Dam St", "address2": null, "address3": "", "city": "Long Island City", "zip_code": "11101", "country": "US", "state": "NY", "display_address": ["47- 11 Van Dam St", "Long Island City, NY 11101"]}, "phone": "+17183619152", "display_phone": "(718) 361-9152", "distance": 9996.588059135383}, {"id": "yXOjBSwyqOKDY7oHx3z7HA", "alias": "tomahawks-jersey-city", "name": "Tomahawks", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/AcR-ExIWOWPNXRr6G5cGQw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/tomahawks-jersey-city?adjust_creative=E1AQMelCA8e5oZKc-yWfhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E1AQMelCA8e5oZKc-yWfhg", "review_count": 8, "categories": [{"alias": "axethrowing", "title": "Axe Throwing"}], "rating": 5.0, "coordinates": {"latitude": 40.7411216, "longitude": -74.0493572}, "transactions": [], "location": {"address1": "7 Sherman Ave", "address2": "Fl 2", "address3": "", "city": "Jersey City", "zip_code": "07307", "country": "US", "state": "NJ", "display_address": ["7 Sherman Ave", "Fl 2", "Jersey City, NJ 07307"]}, "phone": "+12014209722", "display_phone": "(201) 420-9722", "distance": 13556.0314007906}, {"id": "5izrkxTF_OWgwEdgzjNCAA", "alias": "bury-the-hatchet-avenel", "name": "Bury The Hatchet", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/pfWLGpz45YAA3UGLDrY-zg/o.jpg", "is_closed": false, "url": "ht ...

# %%
# Your code here; use a function or loop to retrieve all the results from your original request
import time

def yelp_call(url_params, key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(key)}
    response = requests.get(url, headers=headers, params=url_params)
    # put a loop here and return
    
    df = pd.DataFrame(response.json()['businesses'])
    return df

def all_results(url_params, key):
    num = response.json()['total']
    print('{} total matches found.'.format(num))
    cur = 0
    dfs = []
    while cur < num and cur < 60:
        url_params['offset'] = cur
        dfs.append(yelp_call(url_params, key)) # change for a df
        time.sleep(1) #Wait a second
        cur += 50
    df = pd.concat(dfs, ignore_index=True)
    return df

term = 'vegan'
location = 'NY'
url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit' : 50,
                 'radius' : 20000
             }
df = all_results(url_params, key)
# Out:
# 15 total matches found.

# %%
df.to_csv('y', index = False)

# %%
# read the file 
df = pd.read_csv('y')

# %%
df.head()
# Out:
#    Unnamed: 0                           alias  \
# 0           0                 jajaja-new-york
# 1           1       seasoned-vegan-new-york-2
# 2           2  by-chloe-west-village-new-york
# 3           3                 xyst-new-york-2
# 4           4    urban-vegan-kitchen-new-york
#
#                                           categories  \
# 0  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 1  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...
# 2  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...
# 3  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...
# 4  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 40.7141530317142, 'longitude': -7...  (646) 883-5453
# 1   {'latitude': 40.800664, 'longitude': -73.952757}  (212) 222-0092
# 2   {'latitude': 40.729219, 'longitude': -74.001021}  (212) 290-8000
# 3     {'latitude': 40.73865, 'longitude': -73.99451}  (212) 727-2979
# 4      {'latitude': 40.7302, 'longitude': -74.00368}  (646) 438-9939
#
#        distance                      id  \
# 0   1021.727407  XipQLDbyTl5tsLlyzAWzug
# 1  11150.347604  IJg3TdXz8IzKTfcspmr8MQ
# 2   2703.684572  GtfhGhWmr1kQ4EnFTlwg7w
# 3   3694.092976  h0PVO3fYw37f7VUH4UA3jQ
# 4   2864.313535  RABCwRzA1YCSpIWuk9LgqA
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/ESgm04...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/4cA_jz...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/koyjOM...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/WCXwLf...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/E-r_FT...      False
#
#                                             location                    name  \
# 0  {'address1': '162 E Broadway', 'address2': '',...                  Jajaja
# 1  {'address1': '55 Saint Nicholas Ave', 'address...          Seasoned Vegan
# 2  {'address1': '185 Bleecker St', 'address2': ''...  by CHLOE. West Village
# 3  {'address1': '44 West 17th St', 'address2': No...                    XYST
# 4  {'address1': '41 Carmine St', 'address2': None...     Urban Vegan Kitchen
#
#           phone price  rating  review_count  \
# 0  1.646884e+10    $$     4.5           717
# 1  1.212222e+10    $$     4.0          1053
# 2  1.212291e+10    $$     4.0          1598
# 3  1.212727e+10    $$     4.0           241
# 4  1.646439e+10    $$     4.0           354
#
#                                        transactions  \
# 0  ['restaurant_reservation', 'delivery', 'pickup']
# 1                            ['delivery', 'pickup']
# 2                            ['delivery', 'pickup']
# 3                        ['restaurant_reservation']
# 4                            ['delivery', 'pickup']
#
#                                                  url
# 0  https://www.yelp.com/biz/jajaja-new-york?adjus...
# 1  https://www.yelp.com/biz/seasoned-vegan-new-yo...
# 2  https://www.yelp.com/biz/by-chloe-west-village...
# 3  https://www.yelp.com/biz/xyst-new-york-2?adjus...
# 4  https://www.yelp.com/biz/urban-vegan-kitchen-n...

# %%
df_vegan_ny = df

# %%
df_vegan_ny.head()
# Out:
#   \tUnnamed: 0
# 0          0\t
# 1          1\t
# 2          2\t
# 3          3\t
# 4          4\t
